# %% [markdown]
# <a href="https://colab.research.google.com/github/gp0942/Scryfall2DH/blob/main/Scryfall2DH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# running this cell will load the necessary libraries to run the rest of the workbook

import requests
import json
import pandas as pd
from datetime import date

# %%
# set up scryfall api request
response = requests.get('https://api.scryfall.com/bulk-data')
allcards_url = response.json()['data'][3]['download_uri']
response = requests.get(allcards_url)
cards = response.json()
card_df = pd.DataFrame(cards)

# filter for only english language cards
card_df = card_df[card_df['lang']=='en'].copy()

# filter for only paper playable cards
card_df = card_df[pd.DataFrame(card_df.games.tolist()).isin(['paper']).any(1).values].copy()

cards_df = card_df.copy()

# split out prices and legalities columns
df2 = pd.io.json.json_normalize(card_df['legalities'])
df3 = pd.io.json.json_normalize(card_df['prices'])
df2 = df2[['commander']].copy()
df3 = df3[['usd']].copy()
card_df = pd.concat([card_df.reset_index(),df2,df3],axis=1).drop(['legalities','prices'],axis=1)

# keep only commander legal cards
card_df = card_df[card_df['commander']=='legal'].copy()

# sort columns by name and price, and keep only lowest price for every name
card_df['usd'] = card_df['usd'].astype(float)
card_df = card_df.sort_values(['name','usd'])
card_df = card_df.drop_duplicates('name')
card_df = card_df[['name','set_name','mana_cost','cmc','color_identity','edhrec_rank','usd']].copy()

# create a new column based on 2dh legality
def less_than_2(price):
    if price > 2:
        return 'illegal'
    if price <= 2:
        return 'legal'

# turn the result into a spreadsheet    
card_df['2dh_legal'] = card_df.apply(lambda row: less_than_2(row['usd']),axis=1)
card_df.sort_values(['edhrec_rank'],inplace=True)
card_df.reset_index(inplace=True)

# save the result as a new dated spreadsheet (remove the # in the next line to activate)    
#card_df.to_excel(f'2dh-{date.today()}.xlsx',index=False)

card_df.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#    index               name  ...   usd 2dh_legal
# 0  12481           Sol Ring  ...  1.27     legal
# 1  21999      Command Tower  ...  0.20     legal
# 2  26882      Arcane Signet  ...  0.87     legal
# 3  47812     Exotic Orchard  ...  0.23     legal
# 4  39752  Lightning Greaves  ...  7.39   illegal
#
# [5 rows x 9 columns]

# %%
# compare two spreadsheets to return lists of newly legalized cards and newly illegal cards
old_df = pd.read_excel('2dh-2022-02-10.xlsx').set_index('name')
new_df = pd.read_excel('2dh-2022-02-23.xlsx').set_index('name')
new_legal = new_df[new_df['2dh_legal']=='legal']
old_legal = old_df[old_df['2dh_legal']=='legal']
print('Newly Legal:')
display(new_legal[new_legal.index.isin(old_legal.index)==False].head(50).drop('index',axis=1))
print('Newly Illegal:')
display(new_df.loc[old_legal[old_legal.index.isin(new_legal.index)==False].index].head(50).drop('index',axis=1))
# Out:
# Newly Legal:
#                                                                       set_name  ... 2dh_legal
# name                                                                            ...
# Fellwar Stone                                           Neon Dynasty Commander  ...     legal
# Rhythm of the Wild                                      Neon Dynasty Commander  ...     legal
# Gitaxian Probe                                                    New Phyrexia  ...     legal
# Bedevil                                             Forgotten Realms Commander  ...     legal
# Miscast                                                          Core Set 2021  ...     legal
# Krenko, Tin Street Kingpin                              Neon Dynasty Commander  ...     legal
# Emry, Lurker of the Loch                                Neon Dynasty Commander  ...     legal
# Sai, Master Thopterist                                  Neon Dynasty Commander  ...     legal
# Reflections of Littjara                                               Kaldheim  ...     legal
# Varragoth, Bloodsky Sire                                              Kaldheim  ...     legal
# Glint-Horn Buccaneer                                             Core Set 2020  ...     legal
# Smuggler's Copter                                       Neon Dynasty Commander  ...     legal
# Unmarked Grave                                               Modern Horizons 2  ...     legal
# Plague Myr                                                   Mirrodin Besieged  ...     legal
# Soul's Majesty                                          Neon Dynasty Commander  ...     legal
# Teferi, Temporal Archmage                                      Mystery Booster  ...     legal
# Elvish Warmaster                                                      Kaldheim  ...     legal
# Deep Forest Hermit                                             Modern Horizons  ...     legal
# Heartless Hidetsugu                                                   The List  ...     legal
# Skysovereign, Consul Flagship                           Neon Dynasty Commander  ...     legal
# Mavren Fein, Dusk Apostle                                               Ixalan  ...     legal
# Champion of the Perished                              Innistrad: Midnight Hunt  ...     legal
# Raging Ravine                                           Neon Dynasty Commander  ...     legal
# Tovolar, Dire Overlord // Tovolar, the Midnight...    Innistrad: Midnight Hunt  ...     legal
# Dissipation Field                                            Scars of Mirrodin  ...     legal
# Gideon Blackblade                                             War of the Spark  ...     legal
# Ugin's Nexus                                                   Khans of Tarkir  ...     legal
# Full Moon's Rise                                                     Innistrad  ...     legal
# Niv-Mizzet Reborn                                                     The List  ...     legal
# Dire Fleet Ravager                                                      Ixalan  ...     legal
# Mortivore                                                       Commander 2011  ...     legal
# Cavalier of Thorns                                               Core Set 2020  ...     legal
# Geier Reach Bandit // Vildin-Pack Alpha                 Shadows over Innistrad  ...     legal
# Ox of Agonas                                            Neon Dynasty Commander  ...     legal
# Rat Colony                                                            The List  ...     legal
# Spearbreaker Behemoth                                   Neon Dynasty Commander  ...     legal
# Ward Sliver                                                            Legions  ...     legal
# Capital Punishment                                  Conspiracy: Take the Crown  ...     legal
# Elvish Clancaller                                                Core Set 2019  ...     legal
# On Thin Ice                                                    Modern Horizons  ...     legal
# Lightmine Field                                            Rise of the Eldrazi  ...     legal
# Satoru Umezawa                                          Kamigawa: Neon Dynasty  ...     legal
# Isshin, Two Heavens as One                              Kamigawa: Neon Dynasty  ...     legal
# The Reality Chip                                        Kamigawa: Neon Dynasty  ...     legal
# Arcbound Overseer                                                     The List  ...     legal
# Go-Shintai of Hidden Cruelty                            Kamigawa: Neon Dynasty  ...     legal
# Go-Shintai of Shared Purpose                            Kamigawa: Neon Dynasty  ...     legal
# Go-Shintai of Boundless Vigor                           Kamigawa: Neon Dynasty  ...     legal
# Go-Shintai of Ancient Wars                              Kamigawa: Neon Dynasty  ...     legal
# Go-Shintai of Lost Wisdom                               Kamigawa: Neon Dynasty  ...     legal
#
# [50 rows x 7 columns]
# Newly Illegal
#                                                                 set_name  ... 2dh_legal
# name                                                                      ...
# Talisman of Hierarchy                                    Modern Horizons  ...   illegal
# Wilderness Reclamation                                Ravnica Allegiance  ...   illegal
# Blue Sun's Zenith                                             Masters 25  ...   illegal
# Well of Lost Dreams                                       Commander 2021  ...   illegal
# Vivien, Champion of the Wilds                    War of the Spark Promos  ...   illegal
# Setessan Champion                             Theros Beyond Death Promos  ...   illegal
# Tetsuko Umezawa, Fugitive                                      Dominaria  ...   illegal
# Herald of the Pantheon                                     Magic Origins  ...   illegal
# Necroblossom Snarl                           Strixhaven: School of Mages  ...   illegal
# Mirrodin Besieged                                        Modern Horizons  ...   illegal
# Starfield Mystic                                    Core Set 2020 Promos  ...   illegal
# Render Silent                                              RNA Guild Kit  ...   illegal
# Erebos, Bleak-Hearted                                Theros Beyond Death  ...   illegal
# Legion Warboss                                         Guilds of Ravnica  ...   illegal
# Genesis Chamber                                               Battlebond  ...   illegal
# Gilded Goose                                   Throne of Eldraine Promos  ...   illegal
# Bruna, the Fading Light                                    Eldritch Moon  ...   illegal
# Hanweir Garrison                                           Eldritch Moon  ...   illegal
# Calix, Destiny's Hand                         Theros Beyond Death Promos  ...   illegal
# Mist-Syndicate Naga                                      Modern Horizons  ...   illegal
# Vampire of the Dire Moon                                   Core Set 2020  ...   illegal
# Dismantling Wave                                          Commander 2020  ...   illegal
# Faith's Reward                                                Magic 2013  ...   illegal
# Phyrexian Triniform                                    Commander Legends  ...   illegal
# Conspicuous Snoop                                   Core Set 2021 Promos  ...   illegal
# Nesting Grounds                                           Commander 2020  ...   illegal
# Unsettled Mariner                                        Modern Horizons  ...   illegal
# Dragon's Rage Channeler                                Modern Horizons 2  ...   illegal
# Grazilaxx, Illithid Scholar    Adventures in the Forgotten Realms Promos  ...   illegal
# Drown in Dreams                                  Midnight Hunt Commander  ...   illegal
# Thought Monitor                                        Modern Horizons 2  ...   illegal
# Cavalier of Night                                               The List  ...   illegal
# Dragonlair Spider                                   Planechase Anthology  ...   illegal
# Lair of the Hydra                     Adventures in the Forgotten Realms  ...   illegal
# Honden of Night's Reach                            Champions of Kamigawa  ...   illegal
# Honden of Infinite Rage                                         The List  ...   illegal
# Aura Mutation                                             Commander 2016  ...   illegal
# Pariah                                                     Tenth Edition  ...   illegal
# Sentinel Tower                                                Battlebond  ...   illegal
# Aurelia's Fury                                                 Gatecrash  ...   illegal
# Spectra Ward                                                  Magic 2015  ...   illegal
# Rogue Class                           Adventures in the Forgotten Realms  ...   illegal
# Crash of Rhino Beetles                                    Commander 2018  ...   illegal
# Herald of Anguish                                          Aether Revolt  ...   illegal
# Ever-Watching Threshold                                   Commander 2018  ...   illegal
# One with Nature                                                  Scourge  ...   illegal
# Call to the Grave                                             Magic 2012  ...   illegal
# Bloodmark Mentor                                              Shadowmoor  ...   illegal
# Hive of the Eye Tyrant                Adventures in the Forgotten Realms  ...   illegal
# Voice of the Blessed                           Innistrad: Double Feature  ...   illegal
#
# [50 rows x 7 columns]
